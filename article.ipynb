# %% [markdown]
# # This is a paper

# %% [markdown]
# ## Introduction
#
# Donec ullamcorper orci eu ante ornare, vitae euismod orci sodales. Etiam sagittis tortor elit, vel bibendum velit tristique convallis. Curabitur sit amet erat efficitur, malesuada nisl sit amet, ornare ipsum. Etiam sodales ligula turpis, id tempus est consequat in. Cras scelerisque sapien ex, sit amet sodales massa pharetra vel. Donec facilisis dolor leo, eu volutpat tellus ullamcorper a. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Aliquam tortor lacus, viverra eu consectetur placerat, gravida vitae turpis.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = np.random.random((5,5))
plt.imshow(N);
plt.title('changes on every run');
