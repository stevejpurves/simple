# %% [markdown]
# # This is a paper

# %% [markdown]
# ## Introduction
#
# Nunc ac egestas risus, vitae aliquam est. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Integer scelerisque, ipsum vel euismod finibus, eros enim aliquet turpis, ac feugiat felis massa vitae erat. Integer et dapibus orci. Maecenas arcu velit, tincidunt in bibendum quis, tempor eget purus. Etiam odio turpis, posuere ut feugiat et, lacinia blandit augue. Orci varius natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Aliquam a mauris rutrum, elementum magna tincidunt, gravida lacus.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = np.random.random((50,50))
plt.imshow(N);
